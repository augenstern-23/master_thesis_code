# %% [markdown]
# # 2. Make Matrix with Score per TF and tissue

# %%
source("functions_tf_annotation.r")
source("functions_apl.r")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.r-project.org
#
#
# Bioconductor version 3.15 (BiocManager 1.30.18), R 4.2.1 (2022-06-23)
#
# Warning message:
# “package(s) not installed when version(s) same as current; use `force = TRUE` to
#   re-install: 'APL'”
# Installation paths not writeable, unable to update packages
#   path: /pkg/R-4.2.1-0/lib/R/library
#   packages:
#     AnnotationForge, BBmisc, BH, BiocManager, BiocParallel, Biostrings, Boruta,
#     C50, Cairo, ChIPseeker, Ckmeans.1d.dp, ComplexHeatmap, Cubist, DBI,
#     DEoptimR, DOSE, DT, DelayedMatrixStats, ExomeDepth, FNN, Formula, GGally,
#     GenomeInfoDb, GenomicFeatures, HDF5Array, Hmisc, IRanges, KernSmooth,
#     Lahman, MASS, Matrix, MatrixModels, NMF, R.matlab, R.utils, RCurl, RJSONIO,
#     RMariaDB, RMySQL, RPostgreSQL, RPostgres, RSQLite, RWeka, Rcpp, RcppAnnoy,
# ...

# %%
tissues <- c("brain", "heart", "liver", "lung") 

source("functions_tf_annotation.r")

file_paths <- c(
  "data/fimo/whole_genome/brain/brain_collapsed.tsv",
  "data/fimo/whole_genome/heart/heart_collapsed.tsv",
  "data/fimo/whole_genome/liver/liver_collapsed.tsv",
  "data/fimo/whole_genome/lung/lung_collapsed.tsv"
)  
output_file <- "data/results/matrix_tfs_tissues_raw.tsv" 
combined_df <- combine_and_write_tfs(tissues, file_paths, output_file)
# Out:
# Warning message in df_tmp_tf$tissue <- tissues[i]:
# “Coercing LHS to a list”
# Warning message in df_tmp_tf$tissue <- tissues[i]:
# “Coercing LHS to a list”
# Warning message in df_tmp_tf$tissue <- tissues[i]:
# “Coercing LHS to a list”
# Warning message in df_tmp_tf$tissue <- tissues[i]:
# “Coercing LHS to a list”

# %% [markdown]
# ## 2. Convert TFs to encoding Genes

# %%
df_genes <- convert_tf_to_gene(combined_df)
head(df_genes)
ncol(df_genes)
# Out:
#       ABL1  AEBP2 AHDC1 AHR   IKZF3 AIRE GTF2A1L ALX1 ALX3 ALX4 ⋯ ZSCAN18
# brain 21660 6196  14539 22649 38766 5689 6684    4648 3232 2810 ⋯  8352
# heart  8215 6709   4581 31631 53003 1775 5512     930 1011 1010 ⋯ 13448
# liver  7446 5729   6325 27058 44240 1692 4898     814  815  845 ⋯ 11581
# lung   4955 5206   3232 27259 42672  996 4020     467  533  554 ⋯ 11796
#       ZSCAN2 ZSCAN30 ZSCAN4 ZSCAN5A ZSCAN5B ZSCAN5C ZXDA  ZXDB ZXDC
# brain 12775  64456   20496  14501   3863    10422    8449 3855 71072
# heart  5483  51594   15235  15341   2555     4905   10003 4494 65366
# liver  4708  85524   11959  13045   2338     4217    8998 4009 56646
# lung   3439  82359    9941  11695   1746     3126    7240 3278 59514
